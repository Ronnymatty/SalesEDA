# %% [markdown]
# ## ls command to display all directories

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6011-61C3
#
#  Directory of C:\SalesEDA
#
# 10/17/2022  12:09 AM    <DIR>          .
# 10/17/2022  12:09 AM    <DIR>          ..
# 10/17/2022  12:09 AM    <DIR>          .ipynb_checkpoints
# 10/17/2022  12:10 AM    <DIR>          Sales
# 10/17/2022  12:09 AM                72 SalesEDA.ipynb
#                1 File(s)             72 bytes
#                4 Dir(s)  251,282,063,360 bytes free

# %% [markdown]
# ## This command is used to import all relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
files = [file for file in os.listdir("./Sales")]

for file in files :
    print(file)
# Out:
# AprilSales.txt
# AugustSales.txt
# DecemberSales.txt
# FebruarySales.txt
# JanuarySales.txt
# JulySales.txt
# JuneSales.txt
# MarchSales.txt
# MaySales.txt
# NovemberSales.txt
# OctoberSales.txt
# SeptemberSales.txt

# %%
all_sales = pd.DataFrame()
for file in files :
    df = pd.read_csv("./Sales/"+file, sep=",")
    all_sales = pd.concat([all_sales,df])
    

all_sales
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# 0      04/19/19 08:46             917 1st St, Dallas, TX 75001
# 1                 NaN                                      NaN
# 2      04/07/19 22:30        682 Chestnut St, Boston, MA 02215
# 3      04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 4      04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# ...               ...                                      ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
# [186850 rows x 6 columns]

# %%
all_sales.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
all_sales=all_sales.dropna(how="all")

# %%
all_sales.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
all_sales.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
all_sales["Quantity Ordered"]=pd.to_numeric(all_sales["Quantity Ordered"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\.conda\envs\glo\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Quantity Ordered"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 all_sales["Quantity Ordered"]=pd.to_numeric(all_sales["Quantity Ordered"])
#
# File ~\.conda\envs\glo\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# File ~\.conda\envs\glo\lib\site-packages\pandas\_libs\lib.pyx:2357, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Quantity Ordered" at position 517

# %%
all_sales[all_sales["Quantity Ordered"]=="Quantity Ordered"]
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1149   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1155   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2878   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2893   Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...         ...      ...               ...         ...         ...
# 10000  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 10387  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11399  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11468  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11574  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#        Purchase Address
# 519    Purchase Address
# 1149   Purchase Address
# 1155   Purchase Address
# 2878   Purchase Address
# 2893   Purchase Address
# ...                 ...
# 10000  Purchase Address
# 10387  Purchase Address
# 11399  Purchase Address
# 11468  Purchase Address
# 11574  Purchase Address
#
# [355 rows x 6 columns]

# %%
all_sales=all_sales[all_sales["Quantity Ordered"]!="Quantity Ordered"]

# %%
all_sales[all_sales["Quantity Ordered"]=="Quantity Ordered"]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %%
all_sales["Quantity Ordered"]=pd.to_numeric(all_sales["Quantity Ordered"])

# %%
all_sales["Price Each"]=pd.to_numeric(all_sales["Price Each"])

# %%
all_sales.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %%
all_sales["Month"]=all_sales["Order Date"].str[0:2]

# %%
all_sales
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       176558        USB-C Charging Cable                 2       11.95
# 2       176559  Bose SoundSport Headphones                 1       99.99
# 3       176560                Google Phone                 1      600.00
# 4       176560            Wired Headphones                 1       11.99
# 5       176561            Wired Headphones                 1       11.99
# ...        ...                         ...               ...         ...
# 11681   259353      AAA Batteries (4-pack)                 3        2.99
# 11682   259354                      iPhone                 1      700.00
# 11683   259355                      iPhone                 1      700.00
# 11684   259356      34in Ultrawide Monitor                 1      379.99
# 11685   259357        USB-C Charging Cable                 1       11.95
#
#            Order Date                         Purchase Address Month
# 0      04/19/19 08:46             917 1st St, Dallas, TX 75001    04
# 2      04/07/19 22:30        682 Chestnut St, Boston, MA 02215    04
# 3      04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 4      04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001    04
# 5      04/30/19 09:27        333 8th St, Los Angeles, CA 90001    04
# ...               ...                                      ...   ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09
#
# [185950 rows x 7 columns]

# %%
all_sales["Month"]=all_sales["Month"].astype("int32")

# %%
all_sales.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                 int32
# dtype: object

# %%
all_sales["Sales"]=all_sales["Quantity Ordered"]*all_sales["Price Each"]

# %%
all_sales
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       176558        USB-C Charging Cable                 2       11.95
# 2       176559  Bose SoundSport Headphones                 1       99.99
# 3       176560                Google Phone                 1      600.00
# 4       176560            Wired Headphones                 1       11.99
# 5       176561            Wired Headphones                 1       11.99
# ...        ...                         ...               ...         ...
# 11681   259353      AAA Batteries (4-pack)                 3        2.99
# 11682   259354                      iPhone                 1      700.00
# 11683   259355                      iPhone                 1      700.00
# 11684   259356      34in Ultrawide Monitor                 1      379.99
# 11685   259357        USB-C Charging Cable                 1       11.95
#
#            Order Date                         Purchase Address  Month   Sales
# 0      04/19/19 08:46             917 1st St, Dallas, TX 75001      4   23.90
# 2      04/07/19 22:30        682 Chestnut St, Boston, MA 02215      4   99.99
# 3      04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4      04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5      04/30/19 09:27        333 8th St, Los Angeles, CA 90001      4   11.99
# ...               ...                                      ...    ...     ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001      9    8.97
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016      9  700.00
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016      9  700.00
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016      9  379.99
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016      9   11.95
#
# [185950 rows x 8 columns]

# %%
result=all_sales.groupby("Month").sum()

# %%
result
# Out:
#        Quantity Ordered  Price Each       Sales
# Month
# 1                 10903  1811768.38  1822256.73
# 2                 13449  2188884.72  2202022.42
# 3                 17005  2791207.83  2807100.38
# 4                 20558  3367671.02  3390670.24
# 5                 18667  3135125.13  3152606.75
# 6                 15253  2562025.61  2577802.26
# 7                 16072  2632539.56  2647775.76
# 8                 13448  2230345.42  2244467.88
# 9                 13109  2084992.09  2097560.13
# 10                22703  3715554.83  3736726.88
# 11                19798  3180600.68  3199603.20
# 12                28114  4588415.41  4613443.34

# %%
plt.bar(result.index,result["Sales"])
plt.xlabel("Month")
plt.ylabel("Total Sales per Month")
plt.title("Monthly Sales")
plt.xticks(result.index)
plt.ticklabel_format(style="plain",axis="y")
plt.show()

# %%
result1=all_sales.groupby("Product").sum()

# %%
result1
# Out:
#                             Quantity Ordered  Price Each   Month       Sales
# Product
# 20in Monitor                            4129   451068.99   29336   454148.71
# 27in 4K Gaming Monitor                  6244  2429637.70   44440  2435097.56
# 27in FHD Monitor                        7550  1125974.93   52558  1132424.50
# 34in Ultrawide Monitor                  6199  2348718.19   43304  2355558.01
# AA Batteries (4-pack)                  27635    79015.68  145558   106118.40
# AAA Batteries (4-pack)                 31017    61716.59  146370    92740.83
# Apple Airpods Headphones               15661  2332350.00  109477  2349150.00
# Bose SoundSport Headphones             13457  1332366.75   94113  1345565.43
# Flatscreen TV                           4819  1440000.00   34224  1445700.00
# Google Phone                            5532  3315000.00   38305  3319200.00
# LG Dryer                                 646   387600.00    4383   387600.00
# LG Washing Machine                       666   399600.00    4523   399600.00
# Lightning Charging Cable               23217   323787.10  153092   347094.15
# Macbook Pro Laptop                      4728  8030800.00   33548  8037600.00
# ThinkPad Laptop                         4130  4127958.72   28950  4129958.70
# USB-C Charging Cable                   23975   261740.85  154819   286501.25
# Vareebadd Phone                         2068   826000.00   14309   827200.00
# Wired Headphones                       20557   226395.18  133397   246478.43
# iPhone                                  6849  4789400.00   47941  4794300.00

# %%
plt.barh(result1.index,result1["Quantity Ordered"])
plt.ylabel("Product")
plt.xlabel("Quantity Ordered by Product")
plt.title("Quantity of Product Ordered")
#plt.xticks(result.index,rotation=90)
#plt.ticklabel_format(style="plain",axis="y")
plt.show()

# %%
result2=all_sales.groupby("Product").sum().sort_values(by="Quantity Ordered")

# %%
plt.barh(result2.index,result2["Quantity Ordered"])
plt.ylabel("Product")
plt.xlabel("Quantity Ordered by Product")
plt.title("Quantity of Product Ordered")
#plt.xticks(result.index,rotation=90)
#plt.ticklabel_format(style="plain",axis="y")
plt.show()

# %%
result3=all_sales.groupby("Product").sum().sort_values(by="Quantity Ordered",ascending=False)

# %%
plt.barh(result3.index,result3["Quantity Ordered"])
plt.ylabel("Product")
plt.xlabel("Quantity Ordered by Product")
plt.title("Quantity of Product Ordered")
#plt.xticks(result.index,rotation=90)
#plt.ticklabel_format(style="plain",axis="y")
plt.show()
